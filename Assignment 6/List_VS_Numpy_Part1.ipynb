# %%
l=[]
for i in range(10000):
  l.append(i+1)
l
for i in l:
   l.append(l*5)
l

# %%
import numpy as np
a = np.arange(10000)
a
print(a*5)
# Out:
# [    0     5    10 ... 49985 49990 49995]

# %% [markdown]
# Numpy is faster because it uses optimized c code
