# %%
import numpy as np

# %%
a= np.array((
    [10,20,30,40],
    [50,60,70,80],
    [90,10,110,120]
))

# %%
a[1,:4]
# Out:
# array([50, 60, 70, 80])

# %%
a[:2,:4]
# Out:
# array([[10, 20, 30, 40],
#        [50, 60, 70, 80]])

# %%
a[:3,3]
# Out:
# array([ 40,  80, 120])

# %%
a[1,] = [1,2,3,4]

# %%
a
# Out:
# array([[ 10,  20,  30,  40],
#        [  1,   2,   3,   4],
#        [ 90,  10, 110, 120]])
