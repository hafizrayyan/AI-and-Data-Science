# %%
import numpy as np

# %%
a =np.arange(1,6)

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = np.arange(6,11)

# %%
b
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
print(a+b)
# Out:
# [ 7  9 11 13 15]

# %%
print(a-b)
# Out:
# [-5 -5 -5 -5 -5]

# %%
print(a*b)
# Out:
# [ 6 14 24 36 50]

# %%
print(a/b)
# Out:
# [0.16666667 0.28571429 0.375      0.44444444 0.5       ]

# %%
np.sqrt(a)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        , 2.23606798])

# %%
np.exp(a)
# Out:
# array([  2.71828183,   7.3890561 ,  20.08553692,  54.59815003,
#        148.4131591 ])

# %%
np.sin(a)
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 , -0.95892427])

# %%
c = np.array((
    [1,10,89,45,32]
)
)

# %%
f = (c*9/5)+32
f
# Out:
# array([ 33.8,  50. , 192.2, 113. ,  89.6])
